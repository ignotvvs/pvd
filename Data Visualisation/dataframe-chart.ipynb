# %% [markdown]
# # CHART FROM DATAFRAME
# ---

# %% [markdown]
# ## Creating Chart From DataFrame

# %% [markdown]
# As you remember, a Pandas DataFrame is a two-dimensional data structure that resembles a table with rows and columns. It is a fundamental component in data manipulation and analysis using Python. A DataFrame can contain multiple data sets.
#
# When creating a chart, you can present data from all columns, or you can select a column or set of columns and present data from selected columns on the chart.

# %% [markdown]
# Imagine that the data includes average Euro and Dollar exchange rates for the last four days. To create a line charts, just create a chart as you would for a single data series.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
currency = {'USD':[3.98,3.97,4.09,4.02],'EUR':[4.28,4.47,4.41,4.41]}
df = pd.DataFrame(data=currency)
df.index = [1,2,3,4]
df
# Out:
#     USD   EUR
# 1  3.98  4.28
# 2  3.97  4.47
# 3  4.09  4.41
# 4  4.02  4.41

# %%
df.plot(title='Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# If you would like to chart changes in the exchange rate of only one currency, enter the name of the column that contains the values for that currency.

# %%
df['USD'].plot(title='USD Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'USD Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# ### Tasks

# %% [markdown]
# Create a chart for the Euro currency.

# %%
df[['EUR']].plot(title='EUR Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'EUR Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# The exchange rates in the last 4 days for Pound Sterling (GBP) were: 5.01, 4.87, 4.98, 5.09. Add the values of the new currency to your dataset. Create a chart with EUR and GBP (excluding USD) exchange rates.

# %%
df["GBP"] = [5.01, 4.87, 4.98, 5.09]
df[['GBP', 'EUR']].plot(title='EUR AND GBP Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'EUR AND GBP Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# ## Creating Subplots

# %% [markdown]
# Each series in a DataFrame can be also plotted on a different axis with the using of subplots. The 'layout' parameter specifies the number of rows and columns in which the charts will be placed.

# %%
df.plot(subplots=True, title='Currency Rates', xlabel='Days', ylabel='Exchange Rates', layout=(3,1), grid=True)
# Out:
# array([[<Axes: xlabel='Days', ylabel='Exchange Rates'>],
#        [<Axes: xlabel='Days', ylabel='Exchange Rates'>],
#        [<Axes: xlabel='Days', ylabel='Exchange Rates'>]], dtype=object)

# %% [markdown]
# ### Tasks

# %% [markdown]
# Add a grid to your charts. Search the Internet to find out what parameter you should use to add a grid.

# %% [markdown]
# The travel agency organizes holiday trips to London, Paris and Barcelona. The table below shows the number of tourists who visited the given cities in July and August. Plot the data on a horizontal(!) bar chart. Do not forget to add a chart title and axis descriptions.
#
# Destination | Toursits in July | Tourists in August
# ------------|:----------------:|:-----------------:
# Paris       | 370              | 409
# London      | 202              | 315
# Barcelona   | 584              | 712

# %%
agency = pd.DataFrame({
    "Destination": ["Paris", "London", "Barcelona"],
    "Tourists_in_July": [370, 202, 584],
    "Tourists_in_August": [409, 315, 712]
})
agency.plot.barh(x="Destination", ylabel="Number of tourists", title="The number of tourists who visited destinations in July and August")
# Out:
# <Axes: title={'center': 'The number of tourists who visited destinations in July and August'}, ylabel='Number of tourists'>

# %% [markdown]
# Using the continents.csv file, create separate bar charts to present information about the population and area of the continents.

# %%
continents = pd.read_csv("continents.csv")
continents
# Out:
#        Continent      Area  Population
# 0         Europe  10000000   745173774
# 1           Asia  44614000  4694576167
# 2  North America  24230000   595783465
# 3        Oceania   8510926    44491724
# 4         Africa  30365000  1393676444

# %%
continents.plot.bar(subplots=True, layout=(2,1), x="Continent", title="Area and Population across continents")
# Out:
# array([[<Axes: title={'center': 'Area'}, xlabel='Continent'>],
#        [<Axes: title={'center': 'Population'}, xlabel='Continent'>]],
#       dtype=object)

# %%
employees = pd.read_csv("employees.csv")
employees
# Out:
#    first_name   last_name     sex  age         country  \
# 0       Lucho      Maytum    Male   37  United Kingdom
# 1    Torrance      Brandi    Male   60  Czech Republic
# 2      Missie       Kulic  Female   49          Poland
# 3      Rickie  Somerville    Male   39  Czech Republic
# 4       Gawen     Richarz    Male   50          Poland
# 5     Sadella   Batterham  Female   37  Czech Republic
# 6     Meghann       Dance  Female   20  Czech Republic
# 7     Obidiah    Bradburn    Male   49  Czech Republic
# 8       Dolph     Mesnard    Male   53  Czech Republic
# 9      Fabien  McLanaghan    Male   48  Czech Republic
# 10     Shaina   Gaveltone  Female   58          Poland
# 11  Annemarie      Albers  Female   50          Poland
# 12      Erinn      Borell  Female   36  Czech Republic
# 13     Loydie  Cubbinelli    Male   35  Czech Republic
# 14   Osbourne       Rawet    Male   50          Poland
# 15     Ettore       Ernke    Male   49          Poland
# 16     Mortie    Goodayle    Male   56  Czech Republic
# 17   Courtnay      Creevy    Male   61  Czech Republic
# 18   Rochella        Slym  Female   19          Poland
# 19    Frannie    McMorran    Male   47          Poland
#
#                                job_title start_date     salary
# 0            Mechanical Systems Engineer  2/10/2016  148308.96
# 1                              Paralegal  8/12/2020   57026.74
# 2   Business Systems Development Analyst  2/21/2015  133566.77
# 3                     Speech Pathologist  3/11/2014   53750.68
# 4                 Senior Cost Accountant  7/19/2019  115606.12
# 5                Assistant Media Planner  1/14/2017  136875.05
# 6                       Media Manager II  6/10/2014   44973.70
# 7                    Geological Engineer  12/2/2010   64912.33
# 8               Automation Specialist II  7/21/2012   82159.90
# 9                       Graphic Designer  12/1/2021   63059.52
# 10                       Web Designer II  9/12/2010   21228.29
# 11          Structural Analysis Engineer  3/12/2020  109840.09
# 12                  Help Desk Technician  11/6/2011   22500.03
# 13              Systems Administrator IV  5/13/2014   34415.64
# 14                  Office Assistant III  8/12/2021   41511.02
# 15              Environmental Specialist  3/14/2022  103866.10
# 16                      Product Engineer  5/18/2011   40060.88
# 17                       Legal Assistant  1/14/2015   57492.08
# 18              Account Representative I  10/5/2019  105826.54
# 19          Budget/Accounting Analyst II  3/31/2020   39107.88

# %%
employees.groupby('sex')['salary'].plot.hist()
# Out:
# sex
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: salary, dtype: object
