# %% [markdown]
# # Players

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
players = pd.Series([24, 22, 20, 14], index=["Novak Djokovic", "Rafael Nadal", "Roger Federer", "Pete Sampras"])
players.plot.bar(title="Tennis players who have won the most Grand Slam tournaments", xlabel="Players", ylabel="Number of tournaments")
# Out:
# <Axes: title={'center': 'Tennis players who have won the most Grand Slam tournaments'}, xlabel='Players', ylabel='Number of tournaments'>
