# %% [markdown]
# # People

# %%
import pandas as pd

# %%
people = pd.read_csv('people.csv')
people
# Out:
#      first_name   last_name                            job                race
# 0         Jania       Yoell         Nuclear Power Engineer               Aleut
# 1        Ferdie   Le feaver                        Actuary      South American
# 2        Robena   Tremoulet              Assistant Manager           Uruguayan
# 3       Horacio   Feldklein           Sales Representative           Uruguayan
# 4         Petey      Atrill               Media Manager II  Puget Sound Salish
# 5        Kevina  Vashchenko                     Pharmacist               Asian
# 6        Rowney       Eneas        Systems Administrator I          Indonesian
# 7       Angelle  Lindenfeld          Chief Design Engineer     American Indian
# 8       Babette      Guitel  Analog Circuit Design manager           Menominee
# 9      Iolanthe    Dunckley       Automation Specialist IV               Houma
# 10        Maury       Diess                Sales Associate            Japanese
# ...

# %%
people.tail(2)
# Out:
#    first_name last_name                  job        race
# 18  Teodorico  Smidmoor       Research Nurse       Kiowa
# 19   Ernaline  Stobbart  Software Consultant  Panamanian

# %%
people.iloc[[0,2,4]]
# Out:
#   first_name  last_name                     job                race
# 0      Jania      Yoell  Nuclear Power Engineer               Aleut
# 2     Robena  Tremoulet       Assistant Manager           Uruguayan
# 4      Petey     Atrill        Media Manager II  Puget Sound Salish
