# %% [markdown]
# # Cities in Poland

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('cities-in-poland.csv', delimiter=';')
cities
# Out:
#              City          Region            Province  Areakm2  Population
# 0     Bolesławiec   bolesławiecki        dolnośląskie    23.57       39464
# 1    Nowogrodziec   bolesławiecki        dolnośląskie    16.10        4227
# 2         Bielawa  dzierżoniowski        dolnośląskie    36.21       30987
# 3     Dzierżoniów  dzierżoniowski        dolnośląskie    20.07       34168
# 4         Niemcza  dzierżoniowski        dolnośląskie    19.81        3107
# ..            ...             ...                 ...      ...         ...
# 908   Świnoujście  Świnoujście[a]  zachodniopomorskie   197.23       41276
# 909        Człopa         wałecki  zachodniopomorskie     6.27        2345
# 910   Mirosławiec         wałecki  zachodniopomorskie     2.17        3040
# 911        Tuczno         wałecki  zachodniopomorskie     9.21        1956
# 912         Wałcz         wałecki  zachodniopomorskie    38.17       26033
#
# [913 rows x 5 columns]

# %%
cities.groupby("Province")["Population"].sum().plot.bar()
# Out:
# <Axes: xlabel='Province'>

# %%
cities.groupby("Province")["Areakm2"].max()
# Out:
# Province
# dolnośląskie           292.82
# kujawsko-pomorskie     175.98
# lubelskie              147.47
# lubuskie               278.32
# mazowieckie            517.24
# małopolskie            326.85
# opolskie               123.71
# podkarpackie           116.36
# podlaskie              102.13
# pomorskie              261.96
# warmińsko-mazurskie     88.33
# wielkopolskie          261.91
# zachodniopomorskie     300.55
# łódzkie                293.25
# śląskie                188.73
# świętokrzyskie         109.65
# Name: Areakm2, dtype: float64

# %%
cities.groupby("Province")["Areakm2"].max().plot.bar()
# Out:
# <Axes: xlabel='Province'>
